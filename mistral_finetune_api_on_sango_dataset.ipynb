# %% [markdown]
# # Mistral Fine-tuning API
#
# Check out the docs: https://docs.mistral.ai/capabilities/finetuning/

# %%
# !pip install -q mistralai datasets nltk sacrebleu rouge-score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.

# %% [markdown]
# ## Prepare the dataset
#
# Get the dataset

# %%
! wget https://raw.githubusercontent.com/habibadoum/lingua-franca/main/data/fr_sg_eval_data.jsonl
! wget https://raw.githubusercontent.com/habibadoum/lingua-franca/main/data/fr_sg_train_data.jsonl
# Out:
# --2024-06-30 22:25:49--  https://raw.githubusercontent.com/habibadoum/lingua-franca/main/data/fr_sg_eval_data.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127232 (124K) [text/plain]
# Saving to: ‘fr_sg_eval_data.jsonl’
#
# fr_sg_eval_data.jso 100%[===================>] 124.25K  --.-KB/s    in 0.01s
#
# 2024-06-30 22:25:50 (9.14 MB/s) - ‘fr_sg_eval_data.jsonl’ saved [127232/127232]
#
# --2024-06-30 22:25:50--  https://raw.githubusercontent.com/habibadoum/lingua-franca/main/data/fr_sg_train_data.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25400615 (24M) [text/plain]
# Saving to: ‘fr_sg_train_data.jsonl’
#
# fr_sg_train_data.js 100%[===================>]  24.22M   119MB/s    in 0.2s
#
# 2024-06-30 22:25:51 (119 MB/s) - ‘fr_sg_train_data.jsonl’ saved [25400615/25400615]

# %% [markdown]
# ## Reformat dataset
# If you upload this ultrachat_chunk_train.jsonl to Mistral API, you might encounter an error message “Invalid file format” due to data formatting issues. To reformat the data into the correct format, you can download the reformat_dataset.py script and use it to validate and reformat both the training and evaluation data:

# %%
# download the validation and reformat script
# !wget https://raw.githubusercontent.com/mistralai/mistral-finetune/main/utils/reformat_data.py
# Out:
# --2024-06-29 20:17:08--  https://raw.githubusercontent.com/mistralai/mistral-finetune/main/utils/reformat_data.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3381 (3.3K) [text/plain]
# Saving to: ‘reformat_data.py’
#
# reformat_data.py    100%[===================>]   3.30K  --.-KB/s    in 0s
#
# 2024-06-29 20:17:08 (31.2 MB/s) - ‘reformat_data.py’ saved [3381/3381]

# %%
# validate and reformat the training data
# !python reformat_data.py /content/fr_sg_train_data.jsonl

# %%
# validate the reformat the eval data
# !python reformat_data.py /content/fr_sg_eval_data.jsonl

# %% [markdown]
# ## Upload dataset

# %%
import os
from mistralai.client import MistralClient

api_key = os.environ.get("MISTRAL_API_KEY")
client = MistralClient(api_key=api_key)

train_file = "fr_sg_train_data.jsonl"
eval_file = "fr_sg_eval_data.jsonl"
train_data_splits = []

# %%
with open(eval_file, "rb") as f:
    ultrachat_chunk_eval = client.files.create(file=(eval_file, f))

# %%
with open(train_file, "rb") as f:
    ultrachat_chunk_train = client.files.create(file=(train_file, f))

# %%
import json
def pprint(obj):
    print(json.dumps(obj.dict(), indent=4))

# %%
pprint(ultrachat_chunk_train)
# Out:
# {
#     "id": "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c",
#     "object": "file",
#     "bytes": 21193320,
#     "created_at": 1719692240,
#     "filename": "fr_sg_train_data.jsonl",
#     "purpose": "fine-tune"
# }

# %%
pprint(ultrachat_chunk_eval)
# Out:
# {
#     "id": "4b01fdec-95f3-434c-925f-c01818daa08f",
#     "object": "file",
#     "bytes": 106298,
#     "created_at": 1719692235,
#     "filename": "fr_sg_eval_data.jsonl",
#     "purpose": "fine-tune"
# }

# %% [markdown]
# ## Create a fine-tuning job

# %%
from mistralai.models.jobs import TrainingParameters

created_jobs = client.jobs.create(
    model="open-mistral-7b",
    training_files=[ultrachat_chunk_train.id],
    validation_files=[ultrachat_chunk_eval.id],
    hyperparameters=TrainingParameters(
        training_steps=200,
        learning_rate=0.0001,
        )
)

# %%
pprint(created_jobs)
# Out:
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692942,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": []
# }

# %%
import time

retrieved_job = client.jobs.retrieve(created_jobs.id)
while retrieved_job.status in ["RUNNING", "QUEUED"]:
    retrieved_job = client.jobs.retrieve(created_jobs.id)
    pprint(retrieved_job)
    print(f"Job is {retrieved_job.status}, waiting 10 seconds")
    time.sleep(10)
# Out:
# Streaming output truncated to the last 5000 lines.
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
# ...
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.839342,
#                 "valid_loss": 0.972276,
#                 "valid_mean_token_accuracy": 1.961934
#             },
#             "step_number": 200,
#             "created_at": 1719694010
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.839342,
#                 "valid_loss": 0.972276,
#                 "valid_mean_token_accuracy": 1.961934
#             },
#             "step_number": 200,
#             "created_at": 1719694010
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": null,
#     "model": "open-mistral-7b",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719692943,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.839342,
#                 "valid_loss": 0.972276,
#                 "valid_mean_token_accuracy": 1.961934
#             },
#             "step_number": 200,
#             "created_at": 1719694010
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240629:d82784af",
#     "model": "open-mistral-7b",
#     "status": "SUCCESS",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719694033,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "SUCCESS"
#             },
#             "created_at": 1719694033
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.839342,
#                 "valid_loss": 0.972276,
#                 "valid_mean_token_accuracy": 1.961934
#             },
#             "step_number": 200,
#             "created_at": 1719694010
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }
# Job is SUCCESS, waiting 10 seconds

# %%
# List jobs
jobs = client.jobs.list()
pprint(jobs)
# Out:
# {
#     "data": [
#         {
#             "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#             "hyperparameters": {
#                 "training_steps": 200,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240629:d82784af",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719692942,
#             "modified_at": 1719694033,
#             "training_files": [
#                 "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#             ],
#             "validation_files": [
#                 "4b01fdec-95f3-434c-925f-c01818daa08f"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "14992c62-77d1-4db1-8bc6-0a5267fbf3da",
#             "hyperparameters": {
#                 "training_steps": 100,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240628:14992c62",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719534604,
#             "modified_at": 1719535190,
#             "training_files": [
#                 "0fcc9c78-73e8-4e2a-ac89-b623b759b480"
#             ],
#             "validation_files": [
#                 "17eabff4-7e55-4cfd-991d-e905ac6c792e"
#             ],
#             "object": "job",
#             "integrations": [
#                 {
#                     "type": "wandb",
#                     "project": "test_ft_api",
#                     "name": null,
#                     "run_name": "test"
#                 }
#             ]
#         },
#         {
#             "id": "ae4ffe25-e48f-4438-99a7-aad88b14b26d",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:mistral-small-latest:66e9a26f:20240628:ae4ffe25",
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719534367,
#             "modified_at": 1719534590,
#             "training_files": [
#                 "0fcc9c78-73e8-4e2a-ac89-b623b759b480"
#             ],
#             "validation_files": [
#                 "17eabff4-7e55-4cfd-991d-e905ac6c792e"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "f27244e3-c7b5-4752-b5db-8987a23153a5",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240628:f27244e3",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719533913,
#             "modified_at": 1719534009,
#             "training_files": [
#                 "0fcc9c78-73e8-4e2a-ac89-b623b759b480"
#             ],
#             "validation_files": [
#                 "17eabff4-7e55-4cfd-991d-e905ac6c792e"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "783769d5-3a9d-4e44-a324-b517067bd4a1",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240628:783769d5",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719533299,
#             "modified_at": 1719533394,
#             "training_files": [
#                 "d1452cae-2f9c-4d61-9322-4c31f3364aef"
#             ],
#             "validation_files": [
#                 "898912fe-4e70-43b5-bc18-752885118ce5"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "94b62b35-03b7-487b-881c-e7534a2bcc40",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240622:94b62b35",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1719089521,
#             "modified_at": 1719089596,
#             "training_files": [
#                 "a7ffb1a0-9fee-40fb-b31c-833dc4d9c53e"
#             ],
#             "validation_files": [
#                 "633ed4f9-e072-4008-96f3-13890ad31868"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "44c9c927-d77c-4f01-b30f-4670332a12af",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240621:44c9c927",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1718987178,
#             "modified_at": 1718987289,
#             "training_files": [
#                 "35dd019b-b761-49a3-b143-ec9283073b55",
#                 "776b4946-aeb6-4439-baa6-742fb7dc24ba",
#                 "7e61df93-2f34-4522-b1ae-4781b279f5a5",
#                 "73648e78-d027-43bf-81cb-9493264f2176",
#                 "22ad2cdb-a272-4a9e-a269-e2e4a20d2a36",
#                 "31db22d9-057d-4702-aecf-97c77ab814d7",
#                 "1ecfbd0e-b070-4be6-ac08-a12c5c3aa121",
#                 "b0114274-799e-4b22-9e72-4591dc39773e",
#                 "0669ef9e-4697-4944-9acf-16fe62b7ee38"
#             ],
#             "validation_files": [
#                 "5e82bb02-ebee-4fca-97b9-21c7deeb7ceb"
#             ],
#             "object": "job",
#             "integrations": []
#         },
#         {
#             "id": "0e6067b9-1728-4df3-a4d3-8a4f76395b26",
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001
#             },
#             "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240621:0e6067b9",
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1718962596,
#             "modified_at": 1718962719,
#             "training_files": [
#                 "f42d73ba-f90c-45a5-89b1-dcee822dda9d"
#             ],
#             "validation_files": [
#                 "96c4b90e-30a9-45bf-90e6-2f04824cf1f7"
#             ],
#             "object": "job",
#             "integrations": []
#         }
#     ],
#     "object": "list"
# }

# %%
# Retrieve a jobs
retrieved_jobs = client.jobs.retrieve(created_jobs.id)
pprint(retrieved_jobs)
# Out:
# {
#     "id": "d82784af-b4fa-41fa-a70e-44692e7e3dd6",
#     "hyperparameters": {
#         "training_steps": 200,
#         "learning_rate": 0.0001
#     },
#     "fine_tuned_model": "ft:open-mistral-7b:66e9a26f:20240629:d82784af",
#     "model": "open-mistral-7b",
#     "status": "SUCCESS",
#     "job_type": "FT",
#     "created_at": 1719692942,
#     "modified_at": 1719694033,
#     "training_files": [
#         "ca63c194-cb59-4d2e-ae1a-f3b0ee6a538c"
#     ],
#     "validation_files": [
#         "4b01fdec-95f3-434c-925f-c01818daa08f"
#     ],
#     "object": "job",
#     "integrations": [],
#     "events": [
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "SUCCESS"
#             },
#             "created_at": 1719694033
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "RUNNING"
#             },
#             "created_at": 1719692943
#         },
#         {
#             "name": "status-updated",
#             "data": {
#                 "status": "QUEUED"
#             },
#             "created_at": 1719692942
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 0.839342,
#                 "valid_loss": 0.972276,
#                 "valid_mean_token_accuracy": 1.961934
#             },
#             "step_number": 200,
#             "created_at": 1719694010
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.895091,
#                 "valid_loss": 0.992455,
#                 "valid_mean_token_accuracy": 1.989568
#             },
#             "step_number": 160,
#             "created_at": 1719693802
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.037439,
#                 "valid_loss": 1.101274,
#                 "valid_mean_token_accuracy": 2.14544
#             },
#             "step_number": 120,
#             "created_at": 1719693594
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.390677,
#                 "valid_loss": 1.347628,
#                 "valid_mean_token_accuracy": 2.544933
#             },
#             "step_number": 80,
#             "created_at": 1719693377
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.143023,
#                 "valid_loss": 2.069736,
#                 "valid_mean_token_accuracy": 4.198099
#             },
#             "step_number": 40,
#             "created_at": 1719693170
#         }
#     ],
#     "estimated_start_time": null
# }

# %%
retrieved_jobs.fine_tuned_model
# Out:
# 'ft:open-mistral-7b:66e9a26f:20240629:d82784af'

# %% [markdown]
# ## Use a fine-tuned model

# %%
from mistralai.client import MistralClient

api_key = os.environ.get("MISTRAL_API_KEY")
client = MistralClient(api_key=api_key)

# %%
from mistralai.models.chat_completion import ChatMessage

chat_response = client.chat(
    model=retrieved_jobs.fine_tuned_model,
    messages=[ChatMessage(role='user', content="Traduis en sango: S'il vous offre une bière, refusez-la.")]
)

# %%
message = chat_response.choices[0].message
res = dict(message)
res['content']
# Out:
# 'sango : Mû biëre na mo, kîri na.'

# %%
def read_txt_file_into_list(filename):
  """
  Reads the contents of a text file into a list.

  Args:
    filename: The name of the text file to read.

  Returns:
    A list containing the lines of the text file.
  """

  with open(filename, 'r') as f:
    lines = f.readlines()
  return lines

french_file = 'dev.fra_Latn' # Corpus from FLORES-200
sango_file = 'dev.sag_Latn' # Corpus from FLORES-200
french_data = read_txt_file_into_list(french_file)
sango_data = read_txt_file_into_list(sango_file)

print(f"Number of lines in {french_file}: {len(french_data)}")
print(f"Number of lines in {sango_file}: {len(sango_data)}")
# Out:
# Number of lines in dev.fra_Latn: 997
# Number of lines in dev.sag_Latn: 997

# %% [markdown]
# **Note :** For the `dev.fra_Latn` and `dev.sag_Latn` files, you'll need to download them manually from the [official repository](https://github.com/openlanguagedata/flores) of FLORES-200.
#
# The latest version of the dataset can be downloaded in the Releases tab of this repository. It is available as a zip archive, with password multilingual machine translation. The data is only available in this format in order to avoid it being picked up by crawlers, which would lead to it being accidentally included in the sort of web corpora often used to train LLMs and large scale machine translation models, rendering it useless as a benchmark.

# %%
import time
from mistralai.models.chat_completion import ChatMessage

model_predictions = []

for text in french_data[:100]:
  chat_response = client.chat(
      model=retrieved_jobs.fine_tuned_model,
      messages=[ChatMessage(role='user', content=f"Traduis la phrase suivante en Sango: {text}")]
  )

  pred = chat_response.choices[0].message.content.split('sango :')[-1].strip()
  print(f"Prediction: {pred}")
  model_predictions.append(pred)
# Out:
# Prediction: Alîngbi tî fadësû tî âwandarä tî dalisoro tî Stanford akônda na pekô tî lâsô. Âla sû âgerê tî hînga wala âkêtê kêsi tî sâra tënë sô alöndö na lêgë nî tî hînga sëndëngö sêngê sêngê, sô ayeke tene ngâ tî sâra na gerê tî sû wala tî kutukutu tî mbëtïngû.
# Prediction: Na lêgë tî âmokondö kûê, sô asâra sï, ngbanga tî kobêla tî kankûi, tî kötä-mbs, tî VIH na tî palüsïi na yâ tî âködörö tî nginza tî nî sô ayeke âkutukutu, sï kobêla tî kankûi tî bôbanga tî âwâlï so ague na ngangü, azîa na yâ tî âködörö tî nginza ahön ndönî.
# Prediction: Sango : Masïni-lêgë tî laparaäo sô ayeke lô na yâ tî laparaäo ngâ na tângo tî kä na 9 h 30, lo tïgbïngö, ngâ lo tïngo ngâ lo bira, sï kua tî laparaäo tî wöngö-kôbe a yeke zîa.
# Prediction: Sango : Pilôto atö ndâ tî lo na gbe tî komandâgbo Tilokrit Pattavee.
# Prediction: Lêndo tî wërë sô atene : Mopepe tî lëkëngö-wâ afâ na hürüngö
# Prediction: Sango : Vidal, balë-ôko na mbâgë tî o menë, sî bîakü asï na Barça.
# Prediction: Sango : Lekere ngoi na ngoi sô Vidal alöndö na ndokua tî Katalâna, lo sâra kâmba tî bângâ tî bôsôngbi 49.
# Prediction: Yê sô angbâ tî bâa ndo na pekô tî ngoi sô ayeke gue na ndö tî hônga ndâkua tî mbi, na yâ tî ndö nî tî gbefâ sô ayeke na zûnga tî bûngbi tî mokönzi tî kpëngö-ködörö.
# Prediction: Na ndo tî Whitehall na pekô tî ôko-ôko, balaka tî vôte ayeke kânga lêgë tî kutukutu sô ayeke na ndo na mbäli tî banga.
# Prediction: Sango : Na yâ tî ngbonga balë-ôko na otâ ngoi, âturûgu abûngbi âwakpälë tî küku na lêgë tî âla, sô agbû kpêngba na nzï nî tîtene âla wara ngangü tî dëngö-ndo gï âla, âla wara ngangü tî mû lêgë.
# Prediction: Ngoi asï na 11 h 29, lâkûi agä tî huru na Whitehall, tî lï na Trafalgar Square, na yongôro ngongo tî ndângbâ tî Strand, na yâ tî Aldwych, nînga ngû tî gue na Kingsway, na yâ tî Holborn, na ndo sô Parti ngbanga tenne Kono tî ngû sô na hôtel Grand Connaught Rooms.
# Prediction: Sango : Ndurü tî bende kôzo tî Nadal na Canadîene ayeke ngbonga mîngi.
# Prediction: Sango : A yeke sï na nî
# Prediction: Tî môlengê sô ayeke na ndarä tî dö sâki na lê tî mandako.
# Prediction: Na pekô tî mângo, gbïä tî sêse-girisa ague: “Ambênî mbi laâ angbâ kawâ nî na nî. Mbi laâ tî gue na ngbängö-ndembö tî mabôko nî. Tî gue ngbëndä mbï yeke gue tî gbî âyê tî ndâmbo nî sô nzönî ûse”.
# Prediction: Sango : Lêgë tî mbênî gbândasâki tî Trans-Alaska ayeke kânga na pekô tî bïngö kpöndö na âmâi 800 mile. Âzo kûê ayeke pîka âla na hônde na yâ tî bïngö-ngû tî kpöndö.
# Prediction: Kürü bätängö mabôko tî wâkua tî kpöngö ndo na ngangü tî gerê-wâ sô, sï ngangü tî kängö kä ayeke sïgî na yâ tî mangbôkô tî kutukutu sô na yâ tî gbätä tî âzo tî Fort Greely.

# %%
clean_predictions = [pred.replace("Sango : ", "").strip() for pred in model_predictions]
clean_predictions
# Out:
# ['Alîngbi tî fadësû tî âwandarä tî dalisoro tî Stanford akônda na pekô tî lâsô. Âla sû âgerê tî hînga wala âkêtê kêsi tî sâra tënë sô alöndö na lêgë nî tî hînga sëndëngö sêngê sêngê, sô ayeke tene ngâ tî sâra na gerê tî sû wala tî kutukutu tî mbëtïngû.',
#  'Na lêgë tî âmokondö kûê, sô asâra sï, ngbanga tî kobêla tî kankûi, tî kötä-mbs, tî VIH na tî palüsïi na yâ tî âködörö tî nginza tî nî sô ayeke âkutukutu, sï kobêla tî kankûi tî bôbanga tî âwâlï so ague na ngangü, azîa na yâ tî âködörö tî nginza ahön ndönî.',
#  'Masïni-lêgë tî laparaäo sô ayeke lô na yâ tî laparaäo ngâ na tângo tî kä na 9 h 30, lo tïgbïngö, ngâ lo tïngo ngâ lo bira, sï kua tî laparaäo tî wöngö-kôbe a yeke zîa.',
#  'Pilôto atö ndâ tî lo na gbe tî komandâgbo Tilokrit Pattavee.',
#  'Lêndo tî wërë sô atene : Mopepe tî lëkëngö-wâ afâ na hürüngö',
#  'Vidal, balë-ôko na mbâgë tî o menë, sî bîakü asï na Barça.',
#  'Lekere ngoi na ngoi sô Vidal alöndö na ndokua tî Katalâna, lo sâra kâmba tî bângâ tî bôsôngbi 49.',
#  'Yê sô angbâ tî bâa ndo na pekô tî ngoi sô ayeke gue na ndö tî hônga ndâkua tî mbi, na yâ tî ndö nî tî gbefâ sô ayeke na zûnga tî bûngbi tî mokönzi tî kpëngö-ködörö.',
#  'Na ndo tî Whitehall na pekô tî ôko-ôko, balaka tî vôte ayeke kânga lêgë tî kutukutu sô ayeke na ndo na mbäli tî banga.',
#  'Na yâ tî ngbonga balë-ôko na otâ ngoi, âturûgu abûngbi âwakpälë tî küku na lêgë tî âla, sô agbû kpêngba na nzï nî tîtene âla wara ngangü tî dëngö-ndo gï âla, âla wara ngangü tî mû lêgë.',
#  'Ngoi asï na 11 h 29, lâkûi agä tî huru na Whitehall, tî lï na Trafalgar Square, na yongôro ngongo tî ndângbâ tî Strand, na yâ tî Aldwych, nînga ngû tî gue na Kingsway, na yâ tî Holborn, na ndo sô Parti ngbanga tenne Kono tî ngû sô na hôtel Grand Connaught Rooms.',
#  'Ndurü tî bende kôzo tî Nadal na Canadîene ayeke ngbonga mîngi.',
#  'A yeke sï na nî',
#  'Tî môlengê sô ayeke na ndarä tî dö sâki na lê tî mandako.',
#  'Kürü bätängö mabôko tî wâkua tî kpöngö ndo na ngangü tî gerê-wâ sô, sï ngangü tî kängö kä ayeke sïgî na yâ tî mangbôkô tî kutukutu sô na yâ tî gbätä tî âzo tî Fort Greely.']

# %%
print(f"Len of model_predictions: {len(model_predictions)}")
print(f"First prediction: {model_predictions[0]}")
print(f"Last prediction: {model_predictions[-1]}")
# Out:
# Len of model_predictions: 100
# First prediction: Alîngbi tî fadësû tî âwandarä tî dalisoro tî Stanford akônda na pekô tî lâsô. Âla sû âgerê tî hînga wala âkêtê kêsi tî sâra tënë sô alöndö na lêgë nî tî hînga sëndëngö sêngê sêngê, sô ayeke tene ngâ tî sâra na gerê tî sû wala tî kutukutu tî mbëtïngû.
# Last prediction: Kürü bätängö mabôko tî wâkua tî kpöngö ndo na ngangü tî gerê-wâ sô, sï ngangü tî kängö kä ayeke sïgî na yâ tî mangbôkô tî kutukutu sô na yâ tî gbätä tî âzo tî Fort Greely.

# %%
from datasets import load_metric

references = sango_data[:100]

bleu_metric = load_metric('bleu')

predictions_list = [prediction.split() for prediction in clean_predictions]
references_list = [[reference.split()] for reference in references]

bleu_result = bleu_metric.compute(predictions=predictions_list, references=references_list)
print("BLEU Score:", bleu_result)
# Out:
# BLEU Score: {'bleu': 0.0049036996543233, 'precisions': [0.16145092460881935, 0.01696165191740413, 0.0015308075009567547, 0.000397456279809221], 'brevity_penalty': 0.7675279602865839, 'length_ratio': 0.7907761529808774, 'translation_length': 2812, 'reference_length': 3556}

# %%
import nltk

# Download necessary NLTK resources
nltk.download('wordnet')
nltk.download('omw-1.4')  # Optional, for additional languages

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from sacrebleu import corpus_ter as sacre_corpus_ter
from nltk.translate.meteor_score import meteor_score


def compute_metrics(references, predictions):
    # Tokenize the sentences
    references_tokens = [[ref.split()] for ref in references]
    predictions_tokens = [pred.split() for pred in predictions]

    # BLEU score
    smoothie = SmoothingFunction().method4
    bleu_score = corpus_bleu(references_tokens, predictions_tokens, smoothing_function=smoothie)

    # ROUGE score
    rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = [rouge.score(ref, pred) for ref, pred in zip(references, predictions)]
    avg_rouge1 = sum([score['rouge1'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    avg_rouge2 = sum([score['rouge2'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    avg_rougeL = sum([score['rougeL'].fmeasure for score in rouge_scores]) / len(rouge_scores)

    # METEOR score
    meteor_scores = [meteor_score([ref.split()], pred.split()) for ref, pred in zip(references, predictions)]
    avg_meteor = sum(meteor_scores) / len(meteor_scores)

    # TER score
    ter_score = sacre_corpus_ter(predictions, [references])

    return {
        "BLEU": bleu_score,
        "ROUGE-1": avg_rouge1,
        "ROUGE-2": avg_rouge2,
        "ROUGE-L": avg_rougeL,
        "METEOR": avg_meteor,
        "TER": ter_score.score
    }


metrics = compute_metrics(references, clean_predictions)
metrics
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# {'BLEU': 0.004899409054457557,
#  'ROUGE-1': 0.25038912565100213,
#  'ROUGE-2': 0.03715914406924841,
#  'ROUGE-L': 0.18183284738555094,
#  'METEOR': 0.07671600339921887,
#  'TER': 95.78177727784028}
